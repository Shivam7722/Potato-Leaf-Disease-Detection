# %%
# from zipfile import ZipFile 

# # specifying the zip file name 
# file_name = "/kaggle/input/potato-leafs/PlantVillage"

# # opening the zip file in READ mode 
# with ZipFile(file_name, 'r') as zip: 

#     # extracting all the files 
#     print('Extracting all the files now...') 
#     zip.extractall()

# %% [markdown]
# #### Importing some important libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import models, layers
from keras import regularizers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 40
EPOCHS = 25
CHANNEL = 3

# %% [markdown]
# #### Converting dataset into batches

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '/kaggle/input/potato-leafs/PlantVillage',
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.
# 2022-12-28 10:48:02.727086: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:02.728137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:02.985586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:02.986491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:02.987305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:02.988100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:02.991575: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-28 10:48:03.251367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:03.252257: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:03.252998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:03.253728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:03.254412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:03.255103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.719237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.720195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.720969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.721733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.722445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.723221: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-28 10:48:07.727759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 10:48:07.728472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)  # it shows length 68 inplace of 2152 because we divide the dataset into batches. So 32*68 = 2176
# Out:
# 54

# %%
for image_batch, label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy())
# Out:
# 2022-12-28 10:48:08.244630: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
for image_batch, label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy().astype("int8"))

# %%
for image_batch, label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.title(class_names[label_batch[0]])

# %%
plt.figure(figsize = (8,8))
for image_batch, label_batch in dataset.take(1):
    for i in range(15):
        plt.subplot(5,3,i+1)
        
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %% [markdown]
# #### Creating a function for spliting datset into train, test and validation

# %%
def dataset_partitions(ds, train_split = 0.8, test_split=0.1, val_split=0.1, shuffle = True, shuffle_size = 5):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed = 12)
        
    train_size = int(train_split*ds_size)
    val_size = int(val_split*ds_size)
    
    train_ds = ds.take(train_size)               # it takes 80% data from dataset 'ds'
    val_ds = ds.skip(train_size).take(val_size)  # it takes 10% data from remaining 20% data of dataset
    test_ds = ds.skip(train_size).skip(val_size) # it takes remaining 10% data from dataset
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = dataset_partitions(dataset)

# %%
len(train_ds)
# Out:
# 43

# %%
len(val_ds)
# Out:
# 5

# %%
len(test_ds)
# Out:
# 6

# %% [markdown]
# #### for increasing the training performance fast we perform some operations

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### doing some preprocessing

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# #### for making model more robust we use data augmentation

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)  
])

# %% [markdown]
# #### Building Model

# %% [markdown]
# * Regularization (_kernel_regularizer_) <br>
# Regularization optimizes a model by penalizing complex models, therefore minimizing loss and complexity. Thus this forces our neural network to be simpler. Here we will use an L2 regularizer, as it is the most common and is more stable than an L1 regularizer. Here we’ll add a regularizer to the second and third layers of our network with a learning rate (lr) of 0.01.

# %%
n_classes = 3

models = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,(3,3),activation = 'relu', input_shape = (BATCH_SIZE, IMAGE_SIZE,IMAGE_SIZE, CHANNEL)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,(3,3),activation = 'relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,(3,3),activation = 'relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,(3,3),activation = 'relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,(3,3),activation = 'relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,(3,3),activation = 'relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes, activation='softmax'),        
])

# %%
models.build(input_shape = (BATCH_SIZE, IMAGE_SIZE,IMAGE_SIZE, CHANNEL))

# %% [markdown]
# #### Summary of model

# %%
models.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (40, 256, 256, 3)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (40, 256, 256, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (40, 254, 254, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (40, 127, 127, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (40, 125, 125, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (40, 62, 62, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (40, 60, 60, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (40, 30, 30, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (40, 28, 28, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (40, 14, 14, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (40, 12, 12, 64)          36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (40, 6, 6, 64)            0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (40, 4, 4, 64)            36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (40, 2, 2, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (40, 256)                 0
# _________________________________________________________________
# dense (Dense)                (40, 64)                  16448
# _________________________________________________________________
# dense_1 (Dense)              (40, 3)                   195
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compilation of model

# %%
models.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %% [markdown]
# #### fitting the model

# %%
history = models.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/25
# 2022-12-28 10:48:24.784549: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#
# Epoch 22/25
# 43/43 [==============================] - 3s 75ms/step - loss: 0.3167 - accuracy: 0.9081 - val_loss: 0.3131 - val_accuracy: 0.9000
# Epoch 23/25
# 43/43 [==============================] - 3s 78ms/step - loss: 0.3008 - accuracy: 0.9105 - val_loss: 0.3118 - val_accuracy: 0.8850
# Epoch 24/25
# 43/43 [==============================] - 3s 77ms/step - loss: 0.2998 - accuracy: 0.9093 - val_loss: 0.2797 - val_accuracy: 0.9250
# Epoch 25/25
# 43/43 [==============================] - 3s 76ms/step - loss: 0.2923 - accuracy: 0.9180 - val_loss: 0.3323 - val_accuracy: 0.8900

# %% [markdown]
# #### Checking Scores of model

# %%
scores = models.evaluate(test_ds)
loss, accuracy = scores
# Out:
# 6/6 [==============================] - 4s 128ms/step - loss: 0.3754 - accuracy: 0.8836

# %%
print("Accuracy of model is : ",accuracy*100)
print("Loss of model is : ",loss*100)
# Out:
# Accuracy of model is :  88.36206793785095
# Loss of model is :  37.543466687202454

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 25, 'steps': 43}

# %%
history.params.keys()
# Out:
# dict_keys(['verbose', 'epochs', 'steps'])

# %%
history.history['accuracy']
# Out:
# [0.47732558846473694,
#  0.6110464930534363,
#  0.7343023419380188,
#  0.7749999761581421,
#  0.8215116262435913,
#  0.8569767475128174,
#  0.8500000238418579,
#  0.8639534711837769,
#  0.8674418330192566,
#  0.864534854888916,
#  0.8796511888504028,
#  0.8837209343910217,
#  0.8895348906517029,
#  0.8790697455406189,
#  0.8941860198974609,
#  0.8982558250427246,
#  0.8941860198974609,
#  0.9040697813034058,
#  0.9040697813034058,
#  0.890116274356842,
#  0.9011628031730652,
#  0.9081395268440247,
#  0.9104651212692261,
#  0.9093023538589478,
#  0.9180232286453247]

# %% [markdown]
# #### Plotting graph for better understanding between validation and training

# %%
accu = history.history['accuracy']
val_accu = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,1,1)

plt.plot(range(EPOCHS),accu,label="Training Accuracy")
plt.plot(range(EPOCHS),val_accu,label="Validation Accuracy")

plt.legend(loc='lower right')
plt.title('Training & Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training & Validation Accuracy')

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,1,1)

plt.plot(range(EPOCHS),loss,label="Training Loss")
plt.plot(range(EPOCHS),val_loss,label="Validation Loss")

plt.legend(loc='lower right')
plt.title('Training & Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training & Validation Loss')

# %%
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print('first image to predict')
    plt.imshow(first_image)
    print('actual: ',class_names[first_label])
    
    batch_prediction = models.predict(images_batch)
    print('predicted : ',class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual:  Potato___Late_blight
# predicted :  Potato___Late_blight

# %% [markdown]
# #### Creating a function for making prediction

# %%
def predict(models,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) #creating a batch
    
    predictions = models.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round((np.max(predictions[0])*100),2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(4,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        
        predicted_class, confidence = predict(models, images[i].numpy())
        actual_class = class_names[labels[i]]
        plt.title(f'Actual : {actual_class} \n Predicted : {predicted_class} \n Confidence : {confidence} ')
        plt.axis('off')

# %% [markdown]
# #### Saving model version

# %%
models.save('/kaggle/working/')
# Out:
# 2022-12-28 10:50:28.476364: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
